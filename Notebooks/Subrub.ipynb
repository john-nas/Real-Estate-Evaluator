# %% [markdown]
# # Read suburb data
# ----
#
# #### Note
# * this code will run daily to collect a real estate summary data belong to Victoria suburbs

# %%
# Dependencies and Setup

# %%
# Out:
#       Unnamed: 0      Suburb State  Postcode        Lat         Lng  Domain_id
# 0              0    Abbeyard   VIC      3737 -36.846683  146.696286      607.0
# 1              1  Abbotsford   VIC      3067 -37.802360  144.998362      627.0
# 2              2  Aberfeldie   VIC      3040 -37.749303  144.900631      647.0
# 3              3     Acheron   VIC      3714 -37.187299  145.624559      667.0
# 4              4         Ada   VIC      3833 -37.786563  146.069601    52097.0
# ...          ...         ...   ...       ...        ...         ...        ...
# 2393        2393    Yulecart   VIC      3301 -37.725503  141.894551        NaN
# 2394        2394     Yundool   VIC      3727 -36.246700  145.958135        NaN
# 2395        2395      Yuroke   VIC      3063 -37.593075  144.840123        NaN
# 2396        2396     Yuulong   VIC      3237 -38.650571  143.455420        NaN
# 2397        2397     Zeerust   VIC      3634 -36.226680  145.425012        NaN
#
# [2398 rows x 7 columns]

# %% [markdown]
# ### Get multiple APIs
# * run 400 API call daily to collect Victora uniqe suburbs ID that being used by Domain real estate.

# %%
# Configure gmaps with API key
import pandas as pd
import requests

# Import API key
from api_keys import g_key
import pprint as pprint
# loading the dataframe with all the information that saved in previous task
source_df=pd.read_csv('../VIC.csv')
source_df

start=200
end=2399
for i in range(start,end):

 
   # set up a parameters dictionary
    params = {
        "searchLevel": "suburb",
        "suburb": source_df['Suburb'].iloc[i],
        "state": 'VIC',
  
        "api_key": g_key
    }
 
    # base url
    base_url = "https://api.domain.com.au/v1/addressLocators"
 
    # run a request using our params dictionary
    response = requests.get(base_url, params=params).json()
   
    # extract results
    #results = response['results']
    
    try:
            #append to hotel data frame
      #  pprint(results)
      print(response)
      source_df['Domain_id'].iloc[i]=response[0]['ids'][0]['id']
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Birregurra'}, {'component': 'Postcode', 'shortName': '3242'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4557}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bittern'}, {'component': 'Postcode', 'shortName': '3918'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4567}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Black Hill'}, {'component': 'Postcode', 'shortName': '3350'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4587}]}]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Black Range'}, {'component': 'Postcode', 'shortName': '3381'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4607}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Black Rock'}, {'component': 'Postcode', 'shortName': '3193'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4627}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blackburn'}, {'component': 'Postcode', 'shortName': '3130'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4637}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blackburn North'}, {'component': 'Postcode', 'shortName': '3130'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4657}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blackburn South'}, {'component': 'Postcode', 'shortName': '3130'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4667}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blackwood'}, {'component': 'Postcode', 'shortName': '3458'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4697}]}]
# {'message': '[]'}
# Missing field/result... skipping.
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blairgowrie'}, {'component': 'Postcode', 'shortName': '3942'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4717}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blakeville'}, {'component': 'Postcode', 'shortName': '3342'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4737}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blind Bight'}, {'component': 'Postcode', 'shortName': '3980'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4777}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Blowhard'}, {'component': 'Postcode', 'shortName': '3352'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4797}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bochara'}, {'component': 'Postcode', 'shortName': '3301'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4827}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bogong'}, {'component': 'Postcode', 'shortName': '3699'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4837}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boho'}, {'component': 'Postcode', 'shortName': '3669'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4857}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boho South'}, {'component': 'Postcode', 'shortName': '3669'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4867}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boigbeat'}, {'component': 'Postcode', 'shortName': '3531'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4877}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boinka'}, {'component': 'Postcode', 'shortName': '3490'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4887}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boisdale'}, {'component': 'Postcode', 'shortName': '3860'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4907}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bolangum'}, {'component': 'Postcode', 'shortName': '3387'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 63647}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bolinda'}, {'component': 'Postcode', 'shortName': '3432'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4927}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bolton'}, {'component': 'Postcode', 'shortName': '3546'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4937}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bona Vista'}, {'component': 'Postcode', 'shortName': '3820'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 4987}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bonbeach'}, {'component': 'Postcode', 'shortName': '3196'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5007}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bonegilla'}, {'component': 'Postcode', 'shortName': '3691'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5027}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boneo'}, {'component': 'Postcode', 'shortName': '3939'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5047}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bonn'}, {'component': 'Postcode', 'shortName': '3561'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5057}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bonnie Doon'}, {'component': 'Postcode', 'shortName': '3720'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5067}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boolarong'}, {'component': 'Postcode', 'shortName': '3960'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5107}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boolarra'}, {'component': 'Postcode', 'shortName': '3870'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5117}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boolarra South'}, {'component': 'Postcode', 'shortName': '3870'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5127}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boole Poole'}, {'component': 'Postcode', 'shortName': '3880'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5147}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boolite'}, {'component': 'Postcode', 'shortName': '3392'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 63667}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boomahnoomoonah'}, {'component': 'Postcode', 'shortName': '3728'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5167}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boonah'}, {'component': 'Postcode', 'shortName': '3235'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5177}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boorhaman North'}, {'component': 'Postcode', 'shortName': '3685'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5227}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boorool'}, {'component': 'Postcode', 'shortName': '3953'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5247}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boort'}, {'component': 'Postcode', 'shortName': '3537'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5267}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boosey'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5277}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boralma'}, {'component': 'Postcode', 'shortName': '3682'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5287}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bornes Hill'}, {'component': 'Postcode', 'shortName': '3379'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5297}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boronia'}, {'component': 'Postcode', 'shortName': '3155'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5327}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Borung'}, {'component': 'Postcode', 'shortName': '3518'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5357}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bostocks Creek'}, {'component': 'Postcode', 'shortName': '3260'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5377}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Botanic Ridge'}, {'component': 'Postcode', 'shortName': '3977'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 71157}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boundary Bend'}, {'component': 'Postcode', 'shortName': '3599'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5397}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bowenvale'}, {'component': 'Postcode', 'shortName': '3465'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5407}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boweya'}, {'component': 'Postcode', 'shortName': '3675'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5417}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boweya North'}, {'component': 'Postcode', 'shortName': '3675'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5427}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bowmans Forest'}, {'component': 'Postcode', 'shortName': '3735'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5447}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Box Hill'}, {'component': 'Postcode', 'shortName': '3128'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5477}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Box Hill North'}, {'component': 'Postcode', 'shortName': '3129'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5547}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Box Hill South'}, {'component': 'Postcode', 'shortName': '3128'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5567}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Boxwood'}, {'component': 'Postcode', 'shortName': '3725'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5597}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bradford'}, {'component': 'Postcode', 'shortName': '3463'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5617}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bradvale'}, {'component': 'Postcode', 'shortName': '3361'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5637}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Braeside'}, {'component': 'Postcode', 'shortName': '3195'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5647}]}]
# {'message': '[]'}
# Missing field/result... skipping.
# {'message': '[]'}
# Missing field/result... skipping.
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brandy Creek'}, {'component': 'Postcode', 'shortName': '3821'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5667}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Branxholme'}, {'component': 'Postcode', 'shortName': '3302'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5677}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bravington'}, {'component': 'Postcode', 'shortName': '3821'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5687}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Braybrook'}, {'component': 'Postcode', 'shortName': '3019'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5697}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Breakaway Creek'}, {'component': 'Postcode', 'shortName': '3303'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5717}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Breakwater'}, {'component': 'Postcode', 'shortName': '3219'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5727}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Breamlea'}, {'component': 'Postcode', 'shortName': '3227'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5737}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brenanah'}, {'component': 'Postcode', 'shortName': '3517'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5747}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Briagolong'}, {'component': 'Postcode', 'shortName': '3860'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5787}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Briar Hill'}, {'component': 'Postcode', 'shortName': '3088'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5807}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bridgewater'}, {'component': 'Postcode', 'shortName': '3516'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5857}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bridgewater North'}, {'component': 'Postcode', 'shortName': '3516'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5877}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bridgewater On Loddon'}, {'component': 'Postcode', 'shortName': '3516'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5917}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bright'}, {'component': 'Postcode', 'shortName': '3741'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5937}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brighton'}, {'component': 'Postcode', 'shortName': '3186'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5957}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brighton East'}, {'component': 'Postcode', 'shortName': '3187'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 5997}]}]
# {'message': '[]'}
# Missing field/result... skipping.
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brim'}, {'component': 'Postcode', 'shortName': '3391'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6007}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brimin'}, {'component': 'Postcode', 'shortName': '3685'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6047}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bringalbert'}, {'component': 'Postcode', 'shortName': '3319'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6077}]}]
# {'message': '[]'}
# Missing field/result... skipping.
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Broadford'}, {'component': 'Postcode', 'shortName': '3658'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6097}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Broadmeadows'}, {'component': 'Postcode', 'shortName': '3047'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6127}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bromley'}, {'component': 'Postcode', 'shortName': '3472'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6177}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brookfield'}, {'component': 'Postcode', 'shortName': '3338'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6207}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brooklyn'}, {'component': 'Postcode', 'shortName': '3012'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6227}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brookville'}, {'component': 'Postcode', 'shortName': '3896'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6247}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Broomfield'}, {'component': 'Postcode', 'shortName': '3364'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6267}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Browns Plains'}, {'component': 'Postcode', 'shortName': '3685'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6307}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bruarong'}, {'component': 'Postcode', 'shortName': '3749'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6317}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brumby'}, {'component': 'Postcode', 'shortName': '3885'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6347}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brunswick'}, {'component': 'Postcode', 'shortName': '3056'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6377}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brunswick East'}, {'component': 'Postcode', 'shortName': '3057'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6427}]}]
# {'message': '[]'}
# Missing field/result... skipping.
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Brunswick West'}, {'component': 'Postcode', 'shortName': '3055'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6447}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bruthen'}, {'component': 'Postcode', 'shortName': '3885'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6477}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buangor'}, {'component': 'Postcode', 'shortName': '3375'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6487}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buchan'}, {'component': 'Postcode', 'shortName': '3885'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6497}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buchan South'}, {'component': 'Postcode', 'shortName': '3885'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6507}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buckland'}, {'component': 'Postcode', 'shortName': '3740'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6527}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buckley'}, {'component': 'Postcode', 'shortName': '3240'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6537}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buckley Swamp'}, {'component': 'Postcode', 'shortName': '3301'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6547}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Budgee Budgee'}, {'component': 'Postcode', 'shortName': '3862'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 52237}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Budgeree'}, {'component': 'Postcode', 'shortName': '3870'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6577}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buffalo'}, {'component': 'Postcode', 'shortName': '3958'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6597}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buffalo River'}, {'component': 'Postcode', 'shortName': '3737'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6607}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bulart'}, {'component': 'Postcode', 'shortName': '3314'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6617}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buldah'}, {'component': 'Postcode', 'shortName': '3890'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6627}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bulga'}, {'component': 'Postcode', 'shortName': '3586'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 47917}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bulgana'}, {'component': 'Postcode', 'shortName': '3377'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6637}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bulla'}, {'component': 'Postcode', 'shortName': '3428'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6657}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bullaharre'}, {'component': 'Postcode', 'shortName': '3266'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6667}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bullarook'}, {'component': 'Postcode', 'shortName': '3352'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6677}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bullarto'}, {'component': 'Postcode', 'shortName': '3461'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6687}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bulleen'}, {'component': 'Postcode', 'shortName': '3105'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6707}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bullengarook'}, {'component': 'Postcode', 'shortName': '3437'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6717}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bullioh'}, {'component': 'Postcode', 'shortName': '3700'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6727}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buln Buln'}, {'component': 'Postcode', 'shortName': '3821'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6747}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bumberrah'}, {'component': 'Postcode', 'shortName': '3902'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6777}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bunbartha'}, {'component': 'Postcode', 'shortName': '3634'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6787}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bundalong'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6817}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bundalong South'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6827}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bundara'}, {'component': 'Postcode', 'shortName': '3898'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 52357}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bunding'}, {'component': 'Postcode', 'shortName': '3342'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6837}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bundoora'}, {'component': 'Postcode', 'shortName': '3083'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6877}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bundoora'}, {'component': 'Postcode', 'shortName': '3083'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6877}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bungador'}, {'component': 'Postcode', 'shortName': '3260'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6917}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bungal'}, {'component': 'Postcode', 'shortName': '3334'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6927}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bungeet'}, {'component': 'Postcode', 'shortName': '3726'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6957}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bungeet West'}, {'component': 'Postcode', 'shortName': '3726'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6967}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bunguluke'}, {'component': 'Postcode', 'shortName': '3527'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 6997}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buninyong'}, {'component': 'Postcode', 'shortName': '3357'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7017}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bunyip'}, {'component': 'Postcode', 'shortName': '3815'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7037}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bunyip North'}, {'component': 'Postcode', 'shortName': '3815'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7047}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burkes Flat'}, {'component': 'Postcode', 'shortName': '3475'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7077}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burnbank'}, {'component': 'Postcode', 'shortName': '3371'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7097}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burnewang'}, {'component': 'Postcode', 'shortName': '3558'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7107}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burnley'}, {'component': 'Postcode', 'shortName': '3121'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7117}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burnside'}, {'component': 'Postcode', 'shortName': '3023'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7137}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burnside Heights'}, {'component': 'Postcode', 'shortName': '3023'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 48297}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burramboot'}, {'component': 'Postcode', 'shortName': '3559'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 48307}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burramine'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7167}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burramine South'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7177}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burrowye'}, {'component': 'Postcode', 'shortName': '3709'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7187}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burwood'}, {'component': 'Postcode', 'shortName': '3125'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7237}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Burwood East'}, {'component': 'Postcode', 'shortName': '3151'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7327}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bushfield'}, {'component': 'Postcode', 'shortName': '3281'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7347}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bushy Park'}, {'component': 'Postcode', 'shortName': '3860'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7357}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Butchers Ridge'}, {'component': 'Postcode', 'shortName': '3885'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7367}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Buxton'}, {'component': 'Postcode', 'shortName': '3711'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7377}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Byaduk'}, {'component': 'Postcode', 'shortName': '3301'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7397}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Byaduk North'}, {'component': 'Postcode', 'shortName': '3300'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7407}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Bylands'}, {'component': 'Postcode', 'shortName': '3762'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7437}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Byrneside'}, {'component': 'Postcode', 'shortName': '3617'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7447}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cabarita'}, {'component': 'Postcode', 'shortName': '3505'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7467}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cabbage Tree Creek'}, {'component': 'Postcode', 'shortName': '3889'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7497}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cadello'}, {'component': 'Postcode', 'shortName': '3442'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7507}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cairnlea'}, {'component': 'Postcode', 'shortName': '3023'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7527}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Calder Park'}, {'component': 'Postcode', 'shortName': '3037'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 104257}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Caldermeade'}, {'component': 'Postcode', 'shortName': '3984'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7547}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'California Gully'}, {'component': 'Postcode', 'shortName': '3556'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7567}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Calivil'}, {'component': 'Postcode', 'shortName': '3573'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7587}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Callawadda'}, {'component': 'Postcode', 'shortName': '3387'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 63677}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Callignee'}, {'component': 'Postcode', 'shortName': '3844'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7607}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Callignee North'}, {'component': 'Postcode', 'shortName': '3844'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7627}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Callignee South'}, {'component': 'Postcode', 'shortName': '3844'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 48317}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Calrossie'}, {'component': 'Postcode', 'shortName': '3971'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7647}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Calulu'}, {'component': 'Postcode', 'shortName': '3875'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7657}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cambarville'}, {'component': 'Postcode', 'shortName': '3779'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 52427}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Camberwell'}, {'component': 'Postcode', 'shortName': '3124'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7677}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cambrian Hill'}, {'component': 'Postcode', 'shortName': '3352'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7697}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Campbellfield'}, {'component': 'Postcode', 'shortName': '3061'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7717}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Campbells Bridge'}, {'component': 'Postcode', 'shortName': '3387'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 63687}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Campbells Forest'}, {'component': 'Postcode', 'shortName': '3556'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7777}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Camperdown'}, {'component': 'Postcode', 'shortName': '3260'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7797}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Canadian'}, {'component': 'Postcode', 'shortName': '3350'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7817}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Canary Island'}, {'component': 'Postcode', 'shortName': '3537'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7837}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Caniambo'}, {'component': 'Postcode', 'shortName': '3630'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7847}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cann River'}, {'component': 'Postcode', 'shortName': '3890'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7857}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cannie'}, {'component': 'Postcode', 'shortName': '3540'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7867}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cannons Creek'}, {'component': 'Postcode', 'shortName': '3977'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7877}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cannum'}, {'component': 'Postcode', 'shortName': '3393'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7887}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Canterbury'}, {'component': 'Postcode', 'shortName': '3126'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7907}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cape Bridgewater'}, {'component': 'Postcode', 'shortName': '3305'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7917}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cape Otway'}, {'component': 'Postcode', 'shortName': '3233'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7957}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cape Schanck'}, {'component': 'Postcode', 'shortName': '3939'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7987}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cape Woolamai'}, {'component': 'Postcode', 'shortName': '3925'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 7997}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Capel Sound'}, {'component': 'Postcode', 'shortName': '3940'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 157177}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carag Carag'}, {'component': 'Postcode', 'shortName': '3623'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8027}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Caralulup'}, {'component': 'Postcode', 'shortName': '3371'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8047}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Caramut'}, {'component': 'Postcode', 'shortName': '3274'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8057}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cardinia'}, {'component': 'Postcode', 'shortName': '3978'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8137}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cardross'}, {'component': 'Postcode', 'shortName': '3496'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8147}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Cargerie'}, {'component': 'Postcode', 'shortName': '3334'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8157}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carina'}, {'component': 'Postcode', 'shortName': '3512'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8167}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carisbrook'}, {'component': 'Postcode', 'shortName': '3464'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8187}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carlisle River'}, {'component': 'Postcode', 'shortName': '3239'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8197}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carlsruhe'}, {'component': 'Postcode', 'shortName': '3442'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8207}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carlton'}, {'component': 'Postcode', 'shortName': '3053'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8217}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carlton North'}, {'component': 'Postcode', 'shortName': '3054'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8247}]}]
# {'message': '[]'}
# Missing field/result... skipping.
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carlyle'}, {'component': 'Postcode', 'shortName': '3685'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8267}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carnegie'}, {'component': 'Postcode', 'shortName': '3163'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8297}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Caroline Springs'}, {'component': 'Postcode', 'shortName': '3023'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8327}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carrajung'}, {'component': 'Postcode', 'shortName': '3844'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8367}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carrajung Lower'}, {'component': 'Postcode', 'shortName': '3844'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8397}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carranballac'}, {'component': 'Postcode', 'shortName': '3361'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8447}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carron'}, {'component': 'Postcode', 'shortName': '3480'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8477}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Carrum'}, {'component': 'Postcode', 'shortName': '3197'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 8497}]}]
# ...
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Woorndoo'}, {'component': 'Postcode', 'shortName': '3272'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45057}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wooroonook'}, {'component': 'Postcode', 'shortName': '3525'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45067}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wootong Vale'}, {'component': 'Postcode', 'shortName': '3315'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45087}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wroxham'}, {'component': 'Postcode', 'shortName': '3891'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45117}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wunghnu'}, {'component': 'Postcode', 'shortName': '3635'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45157}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wurdiboluc'}, {'component': 'Postcode', 'shortName': '3241'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45177}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wurruk'}, {'component': 'Postcode', 'shortName': '3850'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45197}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wycheproof'}, {'component': 'Postcode', 'shortName': '3527'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45217}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wycheproof South'}, {'component': 'Postcode', 'shortName': '3527'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45227}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wychitella North'}, {'component': 'Postcode', 'shortName': '3525'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45257}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wye River'}, {'component': 'Postcode', 'shortName': '3234'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 104567}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wyelangta'}, {'component': 'Postcode', 'shortName': '3237'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45287}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wyndham Vale'}, {'component': 'Postcode', 'shortName': '3024'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45307}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wyuna'}, {'component': 'Postcode', 'shortName': '3620'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45327}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Wyuna East'}, {'component': 'Postcode', 'shortName': '3620'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45337}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yaapeet'}, {'component': 'Postcode', 'shortName': '3424'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45347}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yabba North'}, {'component': 'Postcode', 'shortName': '3646'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45367}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yabba South'}, {'component': 'Postcode', 'shortName': '3646'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45377}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yackandandah'}, {'component': 'Postcode', 'shortName': '3749'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45397}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yalca'}, {'component': 'Postcode', 'shortName': '3637'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45407}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yallambie'}, {'component': 'Postcode', 'shortName': '3085'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45427}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yalla-Y-Poora'}, {'component': 'Postcode', 'shortName': '3378'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45417}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yambuk'}, {'component': 'Postcode', 'shortName': '3285'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45467}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yambuna'}, {'component': 'Postcode', 'shortName': '3621'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45487}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yan Yean'}, {'component': 'Postcode', 'shortName': '3755'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45527}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yando'}, {'component': 'Postcode', 'shortName': '3537'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45577}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yandoit Hills'}, {'component': 'Postcode', 'shortName': '3461'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45597}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yangery'}, {'component': 'Postcode', 'shortName': '3283'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45607}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yannathan'}, {'component': 'Postcode', 'shortName': '3981'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45617}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarck'}, {'component': 'Postcode', 'shortName': '3719'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45637}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarpturk'}, {'component': 'Postcode', 'shortName': '3283'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45647}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarra Glen'}, {'component': 'Postcode', 'shortName': '3775'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45657}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarra Junction'}, {'component': 'Postcode', 'shortName': '3797'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45677}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarraberb'}, {'component': 'Postcode', 'shortName': '3516'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45697}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarragon'}, {'component': 'Postcode', 'shortName': '3823'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45707}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarragon South'}, {'component': 'Postcode', 'shortName': '3823'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45717}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarram'}, {'component': 'Postcode', 'shortName': '3971'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45737}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarrambat'}, {'component': 'Postcode', 'shortName': '3091'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45747}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarraville'}, {'component': 'Postcode', 'shortName': '3013'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45777}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarrawalla'}, {'component': 'Postcode', 'shortName': '3575'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45807}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarrawonga'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45827}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yarrawonga South'}, {'component': 'Postcode', 'shortName': '3730'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45837}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yatchaw'}, {'component': 'Postcode', 'shortName': '3301'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45887}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yawong Hills'}, {'component': 'Postcode', 'shortName': '3478'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45907}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yea'}, {'component': 'Postcode', 'shortName': '3717'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45917}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yellingbo'}, {'component': 'Postcode', 'shortName': '3139'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45947}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yelta'}, {'component': 'Postcode', 'shortName': '3505'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45957}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yeodene'}, {'component': 'Postcode', 'shortName': '3249'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45987}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yering'}, {'component': 'Postcode', 'shortName': '3770'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 45997}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yeungroon'}, {'component': 'Postcode', 'shortName': '3525'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46007}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yeungroon East'}, {'component': 'Postcode', 'shortName': '3525'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46017}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yielima'}, {'component': 'Postcode', 'shortName': '3638'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46027}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yinnar'}, {'component': 'Postcode', 'shortName': '3869'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46047}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yinnar South'}, {'component': 'Postcode', 'shortName': '3869'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46057}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'York Plains'}, {'component': 'Postcode', 'shortName': '3477'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 70367}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Youanmite'}, {'component': 'Postcode', 'shortName': '3646'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46067}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Youarang'}, {'component': 'Postcode', 'shortName': '3728'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46077}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yulecart'}, {'component': 'Postcode', 'shortName': '3301'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46087}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yundool'}, {'component': 'Postcode', 'shortName': '3727'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46097}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yuroke'}, {'component': 'Postcode', 'shortName': '3063'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46107}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Yuulong'}, {'component': 'Postcode', 'shortName': '3237'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46117}]}]
# [{'types': ['Suburb'], 'addressComponents': [{'component': 'Suburb', 'shortName': 'Zeerust'}, {'component': 'Postcode', 'shortName': '3634'}, {'component': 'State', 'shortName': 'VIC'}], 'ids': [{'level': 'Suburb', 'id': 46127}]}]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-ad234c8f7527> in <module>
#      12     params = {
#      13         "searchLevel": "suburb",
# ---> 14         "suburb": source_df['Suburb'].iloc[i],
#      15         "state": 'VIC',
#      16
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
source_df.to_csv('../VIC.csv')

# %% [markdown]
# ### clean data from nil;l rows
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#print(source_df.info())
import pandas as pd
source_df=pd.read_csv('../VIC.csv')
source_df=source_df.dropna()

source_df.to_csv('../VIC.csv')
source_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1      Suburb  \
# 0              0             0               0                 0    Abbeyard
# 1              1             1               1                 1  Abbotsford
# 2              2             2               2                 2  Aberfeldie
# 3              3             3               3                 3     Acheron
# 4              4             4               4                 4         Ada
# ...          ...           ...             ...               ...         ...
# 2393        2393          2393            2393              2393    Yulecart
# 2394        2394          2394            2394              2394     Yundool
# 2395        2395          2395            2395              2395      Yuroke
# 2396        2396          2396            2396              2396     Yuulong
# 2397        2397          2397            2397              2397     Zeerust
#
#      State  Postcode        Lat         Lng  Domain_id
# 0      VIC      3737 -36.846683  146.696286      607.0
# 1      VIC      3067 -37.802360  144.998362      627.0
# 2      VIC      3040 -37.749303  144.900631      647.0
# 3      VIC      3714 -37.187299  145.624559      667.0
# 4      VIC      3833 -37.786563  146.069601    52097.0
# ...    ...       ...        ...         ...        ...
# 2393   VIC      3301 -37.725503  141.894551    46087.0
# 2394   VIC      3727 -36.246700  145.958135    46097.0
# 2395   VIC      3063 -37.593075  144.840123    46107.0
# 2396   VIC      3237 -38.650571  143.455420    46117.0
# 2397   VIC      3634 -36.226680  145.425012    46127.0
#
# [2315 rows x 10 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Configure gmaps with API key
import pandas as pd
import requests
import json

# Import API key
from api_keys import g_key
from pprint import pprint 
# loading the dataframe with all the information that saved in previous task
source_df=pd.read_csv('../VIC.csv')

start=1394
end=1894


for index in range(start,end):
    suburb=source_df.iloc[[index]]
    print(source_df['Domain_id'][index])
    
   # set up a parameters dictionary
    params = {
        "propertyCategory":"house",
        "suburbId": source_df['Domain_id'][index],
        "state": 'VIC',
        "chronologicalSpan":3,
        "tPlusFrom":1,
        "tPlusTo":1,
  
        "api_key": g_key
    }
 
    # base url
    base_url = "https://api.domain.com.au/v1/suburbPerformanceStatistics"
 
    
   
    # extract results
    #results = response['results']
    
    try:
    # run a request using our params dictionary
      response = requests.get(base_url, params=params)
            #append to hotel data frame
      #  pprint(results)
      print(len(response.content))
      if (len(response.content)>100):
        response1 = response.json()

        for column in source_df.columns[5:]:
            source_df[column].iloc[index]=response1['series']['seriesInfo'][0]['values'][column]
          
      
    #   source_df['Domain_id'].iloc[i]=response[0]['ids'][0]['id']
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")

# source_df.to_csv('../VIC.csv',index=False)
# Out:
# 28277
# 194
# Missing field/result... skipping.
# 28287
# 194
# Missing field/result... skipping.
# 28297
# 194
# Missing field/result... skipping.
# 28307
# 194
# Missing field/result... skipping.
# 28317
# 194
# Missing field/result... skipping.
# 28337
# 194
# Missing field/result... skipping.
# 28347
# 194
# Missing field/result... skipping.
# 28357
# 194
# Missing field/result... skipping.
# 28377
# 194
# Missing field/result... skipping.
# 28397
# 194
# Missing field/result... skipping.
# 28417
# 194
# Missing field/result... skipping.
# 28437
# 194
# Missing field/result... skipping.
# 28447
# 194
# Missing field/result... skipping.
# 28457
# 194
# Missing field/result... skipping.
# 28477
# 194
# Missing field/result... skipping.
# 28487
# 194
# Missing field/result... skipping.
# 28497
# 194
# Missing field/result... skipping.
# 28507
# 194
# Missing field/result... skipping.
# 28527
# 194
# Missing field/result... skipping.
# 29087
# 194
# Missing field/result... skipping.
# 29107
# 194
# Missing field/result... skipping.
# 29137
# 194
# Missing field/result... skipping.
# 29167
# 194
# Missing field/result... skipping.
# 29187
# 194
# Missing field/result... skipping.
# 29197
# 194
# Missing field/result... skipping.
# 29227
# 194
# Missing field/result... skipping.
# 29237
# 194
# Missing field/result... skipping.
# 29257
# 194
# Missing field/result... skipping.
# 29267
# 194
# Missing field/result... skipping.
# 104437
# 194
# Missing field/result... skipping.
# 29307
# 194
# Missing field/result... skipping.
# 29317
# 194
# Missing field/result... skipping.
# 29367
# 194
# Missing field/result... skipping.
# 29377
# 194
# Missing field/result... skipping.
# 29387
# 194
# Missing field/result... skipping.
# 104447
# 194
# Missing field/result... skipping.
# 29397
# 194
# Missing field/result... skipping.
# 29407
# 194
# Missing field/result... skipping.
# 29417
# 194
# Missing field/result... skipping.
# 29427
# 194
# Missing field/result... skipping.
# 29437
# 194
# Missing field/result... skipping.
# 29467
# 194
# Missing field/result... skipping.
# 29487
# 194
# Missing field/result... skipping.
# 29507
# 194
# Missing field/result... skipping.
# 29537
# 194
# Missing field/result... skipping.
# 29557
# 194
# Missing field/result... skipping.
# 29567
# 194
# Missing field/result... skipping.
# 29597
# 194
# Missing field/result... skipping.
# 29607
# 194
# Missing field/result... skipping.
# 97407
# 194
# Missing field/result... skipping.
# 29657
# 194
# Missing field/result... skipping.
# 29667
# 194
# Missing field/result... skipping.
# 29677
# 194
# Missing field/result... skipping.
# 29697
# 194
# Missing field/result... skipping.
# 29707
# 194
# Missing field/result... skipping.
# 29717
# 194
# Missing field/result... skipping.
# 29727
# 194
# Missing field/result... skipping.
# 29747
# 194
# Missing field/result... skipping.
# 29757
# 194
# Missing field/result... skipping.
# 29767
# 194
# Missing field/result... skipping.
# 29787
# 194
# Missing field/result... skipping.
# 29807
# 194
# Missing field/result... skipping.
# 52287
# 194
# Missing field/result... skipping.
# 29827
# 194
# Missing field/result... skipping.
# 29837
# 194
# Missing field/result... skipping.
# 29847
# 194
# Missing field/result... skipping.
# 29857
# 194
# Missing field/result... skipping.
# 29867
# 194
# Missing field/result... skipping.
# 29877
# 194
# Missing field/result... skipping.
# 48587
# 194
# Missing field/result... skipping.
# 29907
# 194
# Missing field/result... skipping.
# 29917
# 194
# Missing field/result... skipping.
# 29927
# 194
# Missing field/result... skipping.
# 29947
# 194
# Missing field/result... skipping.
# 29957
# 194
# Missing field/result... skipping.
# 29967
# 194
# Missing field/result... skipping.
# 29977
# 194
# Missing field/result... skipping.
# 29987
# 194
# Missing field/result... skipping.
# 30017
# 194
# Missing field/result... skipping.
# 30037
# 194
# Missing field/result... skipping.
# 30047
# 194
# Missing field/result... skipping.
# 30077
# 194
# Missing field/result... skipping.
# 30107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-4bb91c12af89> in <module>
#      40     try:
#      41     # run a request using our params dictionary
# ---> 42       response = requests.get(base_url, params=params)
#      43             #append to hotel data frame
#      44       #  pprint(results)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     426
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#     430         )
#
# ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     470
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#     474         return ssl_context.wrap_socket(sock)
#
# ~\anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\anaconda3\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
from pprint import pprint
pprint(response['series']['seriesInfo'][0]['values'])
print(response['series']['seriesInfo'][0]['values']['daysOnMarket'])
for x in response['series']['seriesInfo'][0]['values']:
          print(x,response['series']['seriesInfo'][0]['values'][x])
# Out:
# {'25thPercentileSoldPrice': 580000,
#  '5thPercentileSoldPrice': 440000,
#  '75thPercentileSoldPrice': 670000,
#  '95thPercentileSoldPrice': 755000,
#  'auctionNumberAuctioned': 15,
#  'auctionNumberSold': 7,
#  'auctionNumberWithdrawn': None,
#  'daysOnMarket': 46,
#  'discountPercentage': None,
#  'highestRentListingPrice': 600,
#  'highestSaleListingPrice': 1575000,
#  'highestSoldPrice': 755000,
#  'lowestRentListingPrice': 277,
#  'lowestSaleListingPrice': 390000,
#  'lowestSoldPrice': 440000,
#  'medianRentListingPrice': 420,
#  'medianSaleListingPrice': 590000,
#  'medianSoldPrice': 600000,
#  'numberRentListing': 19,
#  'numberSaleListing': 34,
#  'numberSold': 19}
# 46
# medianSoldPrice 600000
# numberSold 19
# highestSoldPrice 755000
# lowestSoldPrice 440000
# 5thPercentileSoldPrice 440000
# 25thPercentileSoldPrice 580000
# 75thPercentileSoldPrice 670000
# 95thPercentileSoldPrice 755000
# medianSaleListingPrice 590000
# numberSaleListing 34
# highestSaleListingPrice 1575000
# lowestSaleListingPrice 390000
# auctionNumberAuctioned 15
# auctionNumberSold 7
# auctionNumberWithdrawn None
# daysOnMarket 46
# discountPercentage None
# medianRentListingPrice 420
# numberRentListing 19
# highestRentListingPrice 600
# lowestRentListingPrice 277

# %%
# Add marker layer ontop of heat map
# Use DataFrame.columns()
for column in source_df.columns[5:]:
    print(column)
# Out:
# medianSoldPrice
# numberSold
# highestSoldPrice
# lowestSoldPrice
# medianSaleListingPrice
# numberSaleListing
# highestSaleListingPrice
# lowestSaleListingPrice
# auctionNumberAuctioned
# auctionNumberSold
# auctionNumberWithdrawn
# daysOnMarket
# medianRentListingPrice
# numberRentListing
# highestRentListingPrice
# lowestRentListingPrice

# %%
source_df.to_csv('../VIC.csv',index=False)

# %%
for column in source_df.columns[5:]:
    print(source_df[column].iloc[362])
# Out:
# 600000.0
# 19.0
# 755000.0
# 440000.0
# 590000.0
# 34.0
# 1575000.0
# 390000.0
# 15.0
# 7.0
# nan
# 46.0
# 420.0
# 19.0
# 600.0
# 277.0

# %%
source_df.to_csv('../VIC.csv',index=False)
